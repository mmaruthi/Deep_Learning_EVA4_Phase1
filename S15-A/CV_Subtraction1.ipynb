# %% [markdown]
# <a href="https://colab.research.google.com/github/mmaruthi/Deep_Learning_EVA4_Phase1/blob/master/S15-A/CV_Subtraction1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np

# %%
image1 = cv2.imread("/content/Img21_depth.jpg")
image1
# Out:
# array([[[63, 63, 63],
#         [64, 64, 64],
#         [65, 65, 65],
#         ...,
#         [69, 69, 69],
#         [66, 66, 66],
#         [65, 65, 65]],
#
#        [[63, 63, 63],
#         [64, 64, 64],
#         [66, 66, 66],
#         ...,
#         [70, 70, 70],
#         [67, 67, 67],
#         [66, 66, 66]],
#
#        [[65, 65, 65],
#         [66, 66, 66],
#         [67, 67, 67],
#         ...,
#         [72, 72, 72],
#         [69, 69, 69],
#         [67, 67, 67]],
#
#        ...,
#
#        [[16, 16, 16],
#         [10, 10, 10],
#         [ 7,  7,  7],
#         ...,
#         [19, 19, 19],
#         [23, 23, 23],
#         [30, 30, 30]],
#
#        [[17, 17, 17],
#         [12, 12, 12],
#         [10, 10, 10],
#         ...,
#         [21, 21, 21],
#         [25, 25, 25],
#         [32, 32, 32]],
#
#        [[22, 22, 22],
#         [17, 17, 17],
#         [15, 15, 15],
#         ...,
#         [23, 23, 23],
#         [27, 27, 27],
#         [34, 34, 34]]], dtype=uint8)

# %%
image1.shape
# Out:
# (200, 200, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA6829DC5F8>

# %%
image2 = cv2.imread("/content/Img_fg_bg_3_depth.jpg")

# %%
image2.shape
# Out:
# (200, 200, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA6829DC6D8>

# %%
sub = cv2.subtract(image1, image2)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(sub)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FA6829DC400>
