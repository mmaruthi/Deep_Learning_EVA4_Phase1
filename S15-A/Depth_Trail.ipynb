# %% [markdown]
# <a href="https://colab.research.google.com/github/mmaruthi/Deep_Learning_EVA4_Phase1/blob/master/S15-A/Depth_Trail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/anilbhatt1/EVA4P1_S15_MaskRCNN
# Out:
# Cloning into 'EVA4P1_S15_MaskRCNN'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (211/211), done.
# remote: Total 213 (delta 3), reused 203 (delta 0), pack-reused 0
# Receiving objects: 100% (213/213), 11.94 MiB | 6.02 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
from PIL import Image

foreground = Image.open('/content/EVA4P1_S15_MaskRCNN/FG_Images/Image10.png')
foreground = foreground.convert('L')
foreground = foreground.point(lambda x: 255 if x > 0 else 0 , '1')

background = Image.open('/content/EVA4P1_S15_MaskRCNN/BG_Images/Img10.png')
background = background.convert('L')
background = background.point(lambda x: 0 if x > 0 else 255 , '1')

background.paste(foreground, (50, 50), foreground)

# %%
foreground
# Out:
# <PIL.Image.Image image mode=1 size=200x200 at 0x7FB73491EBE0>

# %%
background
# Out:
# <PIL.Image.Image image mode=1 size=224x224 at 0x7FB73491E908>

# %%
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 235 (delta 0), reused 1 (delta 0), pack-reused 231
# Receiving objects: 100% (235/235), 11.80 MiB | 5.94 MiB/s, done.
# Resolving deltas: 100% (113/113), done.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2020-05-05 12:12:25--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.100.123
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.100.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M  11.9MB/s    in 16s
#
# 2020-05-05 12:12:42 (10.5 MB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
from PIL import Image

foreground = Image.open('/content/EVA4P1_S15_MaskRCNN/FG_Images/Image11.png')

background = Image.open('/content/EVA4P1_S15_MaskRCNN/BG_Images/Img11.png')

background.paste(foreground, (50, 50), foreground)

background.save("./DenseDepth/examples/result.png")

# %%
from PIL import Image

foreground = Image.open('/content/EVA4P1_S15_MaskRCNN/FG_Images/Image11.png')

background = Image.open('/content/EVA4P1_S15_MaskRCNN/BG_Images/Img11.png')

background.paste(foreground, (50, 50), foreground)

background.save("./DenseDepth/examples/result.png")

foreground = Image.open('/content/EVA4P1_S15_MaskRCNN/FG_Images/Image12.png')

background = Image.open('/content/EVA4P1_S15_MaskRCNN/BG_Images/Img12.png')

background.paste(foreground, (50, 50), foreground)

background.save("./DenseDepth/examples/result1.png")

foreground = Image.open('/content/EVA4P1_S15_MaskRCNN/FG_Images/Image13.png')

background = Image.open('/content/EVA4P1_S15_MaskRCNN/BG_Images/Img13.png')

background.paste(foreground, (50, 50), foreground)

background.save("./DenseDepth/examples/result2.png")

# %%
# !cd DenseDepth; python test.py
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (3) images of size (224, 224, 3).
# <Figure size 1000x500 with 1 Axes>

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )
